# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('ds_salaries.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#        'job_title', 'salary', 'salary_currency', 'salary_in_usd',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size'],
#       dtype='object')

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'
    
def seniority(title):
    if 'se' in title.lower() or 'senior' in title.lower() or 'sr' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
            return 'senior'
    elif 'en' in title.lower() or 'jr.' in title.lower():
        return 'jr'
    else:
        return 'na'

# %%
df['job_simp'] = df['job_title'].apply(title_simplifier)

# %%
df.job_simp.value_counts()
# Out:
# job_simp
# data scientist    159
# data engineer     158
# analyst           119
# na                 83
# mle                62
# manager            19
# director            7
# Name: count, dtype: int64

# %%
df['seniority'] = df['job_title'].apply(seniority)

# %%
df.seniority.value_counts()
# Out:
# seniority
# jr        418
# na        146
# senior     43
# Name: count, dtype: int64

# %%
df.company_location.value_counts()
# Out:
# company_location
# US    355
# GB     47
# CA     30
# DE     28
# IN     24
# FR     15
# ES     14
# GR     11
# JP      6
# NL      4
# AT      4
# PT      4
# PL      4
# LU      3
# PK      3
# BR      3
# AE      3
# MX      3
# AU      3
# TR      3
# DK      3
# IT      2
# CZ      2
# SI      2
# RU      2
# CH      2
# NG      2
# CN      2
# BE      2
# VN      1
# EE      1
# AS      1
# DZ      1
# MY      1
# MD      1
# KE      1
# SG      1
# CO      1
# IR      1
# CL      1
# MT      1
# IL      1
# UA      1
# IQ      1
# RO      1
# HR      1
# NZ      1
# HU      1
# HN      1
# IE      1
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#        Unnamed: 0    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#        'job_title', 'salary', 'salary_currency', 'salary_in_usd',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size', 'job_simp', 'seniority'],
#       dtype='object')

# %%
df.job_simp.hist()
# Out:
# <Axes: >

# %%
df.salary.hist()
# Out:
# <Axes: >

# %%
df.employment_type.hist()
# Out:
# <Axes: >

# %%
pd.pivot_table(df,index = 'job_simp', values = 'salary')
# Out:
#                        salary
# job_simp
# analyst         215545.823529
# data engineer   191672.734177
# data scientist  493161.320755
# director        193285.714286
# manager         717953.842105
# mle             320050.532258
# na              331131.168675

# %%
pd.options.display.max_rows
pd.set_option('display.max_rows', None)

# %%
pd.pivot_table(df, index =['company_location', 'job_simp'], values ='salary', aggfunc ='count').sort_values('company_location', ascending =False)
# Out:
#                                  salary
# company_location job_simp
# VN               data scientist       1
# US               na                  38
#                  mle                 25
#                  manager             17
#                  director             2
#                  data scientist      93
#                  data engineer       97
#                  analyst             83
# UA               data scientist       1
# TR               data scientist       1
#                  data engineer        2
# SI               na                   1
#                  mle                  1
# SG               data engineer        1
# RU               na                   2
# RO               data engineer        1
# PT               na                   2
#                  mle                  2
# PL               mle                  1
#                  director             1
#                  data scientist       1
#                  data engineer        1
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#        'job_title', 'salary', 'salary_currency', 'salary_in_usd',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size', 'job_simp', 'seniority'],
#       dtype='object')

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
words = " ".join(df['job_title'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered


words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 2000, width =800, height = 1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 14
#      10             filtered.append(w.lower())
#      11     return filtered
# ---> 14 words_filtered = punctuation_stop(words)
#      16 text = " ".join([ele for ele in words_filtered])
#      18 wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 2000, width =800, height = 1500)
#
# Cell In[42], line 6, in punctuation_stop(text)
#       4 """remove punctuation and stop words"""
#       5 filtered = []
# ----> 6 stop_words = set(stopwords.words('english'))
#       7 word_tokens = word_tokenize(text)
#       8 for w in word_tokens:
#
# NameError: name 'stopwords' is not defined
